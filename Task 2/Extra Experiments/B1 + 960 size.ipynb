# %%
import tensorflow as tf
import keras 
import matplotlib.pyplot as plt
import numpy as np
import cv2
import os
import sys
import random
import os                      
import numpy as np              
import pandas as pd             
import torch             
from PIL import Image, ImageOps, ImageFilter
import matplotlib.pyplot as plt 
import torch.nn as nn           
from torch.utils.data import DataLoader  
from PIL import Image          
import torch.nn.functional as F 
import torchvision.transforms as transforms   
from torchvision.utils import make_grid    
from torchvision.datasets import ImageFolder  
from torch.utils.data import random_split
from tensorflow.keras.layers import Input

# %matplotlib inline
# Out:
# 2024-03-16 17:21:45.794588: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-03-16 17:21:45.794695: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-03-16 17:21:45.926759: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered

# %%
from keras.preprocessing import image
from keras.applications.imagenet_utils import decode_predictions, preprocess_input
from keras.models import Model
from keras.layers import Flatten, Dense, Dropout

# %%
input_shape = (960, 960, 3)
input_layer = Input(shape=input_shape)
model = keras.applications.EfficientNetB1(input_tensor=input_layer,weights='imagenet', include_top=True)
# Out:
# Downloading data from https://storage.googleapis.com/keras-applications/efficientnetb1.h5
# 32148312/32148312 ━━━━━━━━━━━━━━━━━━━━ 2s 0us/step

# %%
for layer in model.layers[0:8]:
    layer.trainable = False
    
    
for i, layer in enumerate(model.layers):
    print(i, layer.name, layer.trainable)
# Out:
# 0 input_layer False
# 1 rescaling False
# 2 normalization False
# 3 rescaling_1 False
# 4 stem_conv_pad False
# 5 stem_conv False
# 6 stem_bn False
# 7 stem_activation False
# 8 block1a_dwconv True
# 9 block1a_bn True
# 10 block1a_activation True
# 11 block1a_se_squeeze True
# 12 block1a_se_reshape True
# 13 block1a_se_reduce True
# 14 block1a_se_expand True
# 15 block1a_se_excite True
# 16 block1a_project_conv True
# 17 block1a_project_bn True
# 18 block1b_dwconv True
# 19 block1b_bn True
# 20 block1b_activation True
# 21 block1b_se_squeeze True
# 22 block1b_se_reshape True
# 23 block1b_se_reduce True
# 24 block1b_se_expand True
# 25 block1b_se_excite True
# 26 block1b_project_conv True
# 27 block1b_project_bn True
# 28 block1b_drop True
# 29 block1b_add True
# 30 block2a_expand_conv True
# 31 block2a_expand_bn True
# 32 block2a_expand_activation True
# 33 block2a_dwconv_pad True
# 34 block2a_dwconv True
# 35 block2a_bn True
# 36 block2a_activation True
# 37 block2a_se_squeeze True
# 38 block2a_se_reshape True
# 39 block2a_se_reduce True
# 40 block2a_se_expand True
# 41 block2a_se_excite True
# 42 block2a_project_conv True
# 43 block2a_project_bn True
# 44 block2b_expand_conv True
# 45 block2b_expand_bn True
# 46 block2b_expand_activation True
# 47 block2b_dwconv True
# 48 block2b_bn True
# 49 block2b_activation True
# 50 block2b_se_squeeze True
# 51 block2b_se_reshape True
# 52 block2b_se_reduce True
# 53 block2b_se_expand True
# 54 block2b_se_excite True
# 55 block2b_project_conv True
# 56 block2b_project_bn True
# 57 block2b_drop True
# 58 block2b_add True
# 59 block2c_expand_conv True
# 60 block2c_expand_bn True
# 61 block2c_expand_activation True
# 62 block2c_dwconv True
# 63 block2c_bn True
# 64 block2c_activation True
# 65 block2c_se_squeeze True
# 66 block2c_se_reshape True
# 67 block2c_se_reduce True
# 68 block2c_se_expand True
# 69 block2c_se_excite True
# 70 block2c_project_conv True
# 71 block2c_project_bn True
# 72 block2c_drop True
# 73 block2c_add True
# 74 block3a_expand_conv True
# 75 block3a_expand_bn True
# 76 block3a_expand_activation True
# 77 block3a_dwconv_pad True
# 78 block3a_dwconv True
# 79 block3a_bn True
# 80 block3a_activation True
# 81 block3a_se_squeeze True
# 82 block3a_se_reshape True
# 83 block3a_se_reduce True
# 84 block3a_se_expand True
# 85 block3a_se_excite True
# 86 block3a_project_conv True
# 87 block3a_project_bn True
# 88 block3b_expand_conv True
# 89 block3b_expand_bn True
# 90 block3b_expand_activation True
# 91 block3b_dwconv True
# 92 block3b_bn True
# 93 block3b_activation True
# 94 block3b_se_squeeze True
# 95 block3b_se_reshape True
# 96 block3b_se_reduce True
# 97 block3b_se_expand True
# 98 block3b_se_excite True
# 99 block3b_project_conv True
# 100 block3b_project_bn True
# 101 block3b_drop True
# 102 block3b_add True
# 103 block3c_expand_conv True
# 104 block3c_expand_bn True
# 105 block3c_expand_activation True
# 106 block3c_dwconv True
# 107 block3c_bn True
# 108 block3c_activation True
# 109 block3c_se_squeeze True
# 110 block3c_se_reshape True
# 111 block3c_se_reduce True
# 112 block3c_se_expand True
# 113 block3c_se_excite True
# 114 block3c_project_conv True
# 115 block3c_project_bn True
# 116 block3c_drop True
# 117 block3c_add True
# 118 block4a_expand_conv True
# 119 block4a_expand_bn True
# 120 block4a_expand_activation True
# 121 block4a_dwconv_pad True
# 122 block4a_dwconv True
# 123 block4a_bn True
# 124 block4a_activation True
# 125 block4a_se_squeeze True
# 126 block4a_se_reshape True
# 127 block4a_se_reduce True
# 128 block4a_se_expand True
# 129 block4a_se_excite True
# 130 block4a_project_conv True
# 131 block4a_project_bn True
# 132 block4b_expand_conv True
# 133 block4b_expand_bn True
# 134 block4b_expand_activation True
# 135 block4b_dwconv True
# 136 block4b_bn True
# 137 block4b_activation True
# 138 block4b_se_squeeze True
# 139 block4b_se_reshape True
# 140 block4b_se_reduce True
# 141 block4b_se_expand True
# 142 block4b_se_excite True
# 143 block4b_project_conv True
# 144 block4b_project_bn True
# 145 block4b_drop True
# 146 block4b_add True
# 147 block4c_expand_conv True
# 148 block4c_expand_bn True
# 149 block4c_expand_activation True
# 150 block4c_dwconv True
# 151 block4c_bn True
# 152 block4c_activation True
# 153 block4c_se_squeeze True
# 154 block4c_se_reshape True
# 155 block4c_se_reduce True
# 156 block4c_se_expand True
# 157 block4c_se_excite True
# 158 block4c_project_conv True
# 159 block4c_project_bn True
# 160 block4c_drop True
# 161 block4c_add True
# 162 block4d_expand_conv True
# 163 block4d_expand_bn True
# 164 block4d_expand_activation True
# 165 block4d_dwconv True
# 166 block4d_bn True
# 167 block4d_activation True
# 168 block4d_se_squeeze True
# 169 block4d_se_reshape True
# 170 block4d_se_reduce True
# 171 block4d_se_expand True
# 172 block4d_se_excite True
# 173 block4d_project_conv True
# 174 block4d_project_bn True
# 175 block4d_drop True
# 176 block4d_add True
# 177 block5a_expand_conv True
# 178 block5a_expand_bn True
# 179 block5a_expand_activation True
# 180 block5a_dwconv True
# 181 block5a_bn True
# 182 block5a_activation True
# 183 block5a_se_squeeze True
# 184 block5a_se_reshape True
# 185 block5a_se_reduce True
# 186 block5a_se_expand True
# 187 block5a_se_excite True
# 188 block5a_project_conv True
# 189 block5a_project_bn True
# 190 block5b_expand_conv True
# 191 block5b_expand_bn True
# 192 block5b_expand_activation True
# 193 block5b_dwconv True
# 194 block5b_bn True
# 195 block5b_activation True
# 196 block5b_se_squeeze True
# 197 block5b_se_reshape True
# 198 block5b_se_reduce True
# 199 block5b_se_expand True
# 200 block5b_se_excite True
# 201 block5b_project_conv True
# 202 block5b_project_bn True
# 203 block5b_drop True
# 204 block5b_add True
# 205 block5c_expand_conv True
# 206 block5c_expand_bn True
# 207 block5c_expand_activation True
# 208 block5c_dwconv True
# 209 block5c_bn True
# 210 block5c_activation True
# 211 block5c_se_squeeze True
# 212 block5c_se_reshape True
# 213 block5c_se_reduce True
# 214 block5c_se_expand True
# 215 block5c_se_excite True
# 216 block5c_project_conv True
# 217 block5c_project_bn True
# 218 block5c_drop True
# 219 block5c_add True
# 220 block5d_expand_conv True
# 221 block5d_expand_bn True
# 222 block5d_expand_activation True
# 223 block5d_dwconv True
# 224 block5d_bn True
# 225 block5d_activation True
# 226 block5d_se_squeeze True
# 227 block5d_se_reshape True
# 228 block5d_se_reduce True
# 229 block5d_se_expand True
# 230 block5d_se_excite True
# 231 block5d_project_conv True
# 232 block5d_project_bn True
# 233 block5d_drop True
# 234 block5d_add True
# 235 block6a_expand_conv True
# 236 block6a_expand_bn True
# 237 block6a_expand_activation True
# 238 block6a_dwconv_pad True
# 239 block6a_dwconv True
# 240 block6a_bn True
# 241 block6a_activation True
# 242 block6a_se_squeeze True
# 243 block6a_se_reshape True
# 244 block6a_se_reduce True
# 245 block6a_se_expand True
# 246 block6a_se_excite True
# 247 block6a_project_conv True
# 248 block6a_project_bn True
# 249 block6b_expand_conv True
# 250 block6b_expand_bn True
# 251 block6b_expand_activation True
# 252 block6b_dwconv True
# 253 block6b_bn True
# 254 block6b_activation True
# 255 block6b_se_squeeze True
# 256 block6b_se_reshape True
# 257 block6b_se_reduce True
# 258 block6b_se_expand True
# 259 block6b_se_excite True
# 260 block6b_project_conv True
# 261 block6b_project_bn True
# 262 block6b_drop True
# 263 block6b_add True
# 264 block6c_expand_conv True
# 265 block6c_expand_bn True
# 266 block6c_expand_activation True
# 267 block6c_dwconv True
# 268 block6c_bn True
# 269 block6c_activation True
# 270 block6c_se_squeeze True
# 271 block6c_se_reshape True
# 272 block6c_se_reduce True
# 273 block6c_se_expand True
# 274 block6c_se_excite True
# 275 block6c_project_conv True
# 276 block6c_project_bn True
# 277 block6c_drop True
# 278 block6c_add True
# 279 block6d_expand_conv True
# 280 block6d_expand_bn True
# 281 block6d_expand_activation True
# 282 block6d_dwconv True
# 283 block6d_bn True
# 284 block6d_activation True
# 285 block6d_se_squeeze True
# 286 block6d_se_reshape True
# 287 block6d_se_reduce True
# 288 block6d_se_expand True
# 289 block6d_se_excite True
# 290 block6d_project_conv True
# 291 block6d_project_bn True
# 292 block6d_drop True
# 293 block6d_add True
# 294 block6e_expand_conv True
# 295 block6e_expand_bn True
# 296 block6e_expand_activation True
# 297 block6e_dwconv True
# 298 block6e_bn True
# 299 block6e_activation True
# 300 block6e_se_squeeze True
# 301 block6e_se_reshape True
# 302 block6e_se_reduce True
# 303 block6e_se_expand True
# 304 block6e_se_excite True
# 305 block6e_project_conv True
# 306 block6e_project_bn True
# 307 block6e_drop True
# 308 block6e_add True
# 309 block7a_expand_conv True
# 310 block7a_expand_bn True
# 311 block7a_expand_activation True
# 312 block7a_dwconv True
# 313 block7a_bn True
# 314 block7a_activation True
# 315 block7a_se_squeeze True
# 316 block7a_se_reshape True
# 317 block7a_se_reduce True
# 318 block7a_se_expand True
# 319 block7a_se_excite True
# 320 block7a_project_conv True
# 321 block7a_project_bn True
# 322 block7b_expand_conv True
# 323 block7b_expand_bn True
# 324 block7b_expand_activation True
# 325 block7b_dwconv True
# 326 block7b_bn True
# 327 block7b_activation True
# 328 block7b_se_squeeze True
# 329 block7b_se_reshape True
# 330 block7b_se_reduce True
# 331 block7b_se_expand True
# 332 block7b_se_excite True
# 333 block7b_project_conv True
# 334 block7b_project_bn True
# 335 block7b_drop True
# 336 block7b_add True
# 337 top_conv True
# 338 top_bn True
# 339 top_activation True
# 340 avg_pool True
# 341 top_dropout True
# 342 predictions True

# %%
model = Model(inputs=model.input, outputs=model.get_layer("avg_pool").output)
model.input
# Out:
# [<KerasTensor shape=(None, 960, 960, 3), dtype=float32, sparse=None, name=keras_tensor>]

# %%
x = model.output
x = Dense(3, activation='softmax')(x)
model = Model(inputs=model.input, outputs=x)

# %%
from keras.callbacks import ReduceLROnPlateau
from keras.callbacks import ModelCheckpoint

lr_reduce = ReduceLROnPlateau(monitor='val_accuracy', factor=0.6, patience=8, verbose=1, mode='max', min_lr=5e-5)
checkpoint = ModelCheckpoint('EFNetB7-ft.keras', monitor= 'val_accuracy', mode= 'max', save_best_only = True, verbose= 1)

# %%
import glob
data = glob.glob('/kaggle/input/transcend/train_images/train_images/*.*')

# %%
data[:5]
# Out:
# ['/kaggle/input/transcend/train_images/train_images/IMG_160.jpg',
#  '/kaggle/input/transcend/train_images/train_images/IMG_21.jpg',
#  '/kaggle/input/transcend/train_images/train_images/IMG_163.jpg',
#  '/kaggle/input/transcend/train_images/train_images/IMG_151.jpg',
#  '/kaggle/input/transcend/train_images/train_images/IMG_190.jpg']

# %%
ann = pd.read_csv('/kaggle/input/transcend/train_annotations.csv')
ann
# Out:
#             Name       State
# 0      IMG_1.jpg   malignant
# 1      IMG_2.jpg  non-nodule
# 2      IMG_3.jpg  non-nodule
# 3      IMG_4.jpg   malignant
# 4      IMG_5.jpg  non-nodule
# ..           ...         ...
# 195  IMG_196.jpg   malignant
# 196  IMG_197.jpg   malignant
# 197  IMG_198.jpg  non-nodule
# 198  IMG_199.jpg   malignant
# 199  IMG_200.jpg      benign
#
# [200 rows x 2 columns]

# %%
from PIL import Image, ImageOps, ImageFilter
image = Image.open('/kaggle/input/transcend/train_images/train_images/IMG_121.jpg').convert('RGB')

# %%
image.size
# Out:
# (2048, 2048)

# %%
ann['State'].replace({'benign': 0, 'non-nodule': 1, 'malignant': 2}, inplace=True)
ann
# Out:
# /tmp/ipykernel_34/1362740101.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   ann['State'].replace({'benign': 0, 'non-nodule': 1, 'malignant': 2}, inplace=True)
# /tmp/ipykernel_34/1362740101.py:1: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   ann['State'].replace({'benign': 0, 'non-nodule': 1, 'malignant': 2}, inplace=True)
#             Name  State
# 0      IMG_1.jpg      2
# 1      IMG_2.jpg      1
# 2      IMG_3.jpg      1
# 3      IMG_4.jpg      2
# 4      IMG_5.jpg      1
# ..           ...    ...
# 195  IMG_196.jpg      2
# 196  IMG_197.jpg      2
# 197  IMG_198.jpg      1
# 198  IMG_199.jpg      2
# 199  IMG_200.jpg      0
#
# [200 rows x 2 columns]

# %%
labels = []

for image_name in data:
    img_file_name = image_name.split('/')[-1]
    label = ann[ann['Name'] == img_file_name]['State'].values[0]
    labels.append(label)

# %%
from PIL import Image, ImageOps, ImageFilter
import numpy as np
import os
from sklearn.utils import shuffle

images = []

def preprocess_image(image_path):
    image = Image.open(image_path).convert('RGB')
    width, height = image.size
    pad = 960
    image = image.resize((pad, pad))
    image = image.filter(ImageFilter.SHARPEN)
    image = np.array(image)
    images.append(image)


for i in data:
    preprocess_image(i)

# %%
images = np.array(images)
images.shape
# Out:
# (200, 960, 960, 3)

# %%
labels= np.array(labels)

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(images, labels, test_size=0.2, random_state=42)

# %%
from tensorflow.keras import layers, models, Model, optimizers
learning_rate= 5e-5
model.compile(loss="sparse_categorical_crossentropy", optimizer=optimizers.Adam(), metrics=["accuracy"])
history = model.fit(X_train, y_train, batch_size = 4, epochs=30, validation_data=(X_test,y_test), callbacks=[lr_reduce,checkpoint])
# Out:
# Epoch 1/30
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1710609945.223233     107 device_compiler.h:186] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# W0000 00:00:1710609945.352985     107 graph_launch.cc:671] Fallback to op-by-op mode because memset node breaks graph update
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 309ms/step - accuracy: 0.4014 - loss: 1.1778
# W0000 00:00:1710609965.541033     107 graph_launch.cc:671] Fallback to op-by-op mode because memset node breaks graph update
# Epoch 1: val_accuracy improved from -inf to 0.17500, saving model to EFNetB7-ft.keras
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 157s 557ms/step - accuracy: 0.4022 - loss: 1.1777 - val_accuracy: 0.1750 - val_loss: 2.0176 - learning_rate: 0.0010
# Epoch 2/30
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 308ms/step - accuracy: 0.5522 - loss: 0.9183
# Epoch 2: val_accuracy improved from 0.17500 to 0.32500, saving model to EFNetB7-ft.keras
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 14s 354ms/step - accuracy: 0.5516 - loss: 0.9196 - val_accuracy: 0.3250 - val_loss: 1.6170 - learning_rate: 0.0010
# Epoch 3/30
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 308ms/step - accuracy: 0.5867 - loss: 0.9341
# Epoch 3: val_accuracy did not improve from 0.32500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 13s 325ms/step - accuracy: 0.5863 - loss: 0.9352 - val_accuracy: 0.3250 - val_loss: 1.5658 - learning_rate: 0.0010
# Epoch 4/30
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 308ms/step - accuracy: 0.5347 - loss: 1.0369
# Epoch 4: val_accuracy did not improve from 0.32500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 13s 325ms/step - accuracy: 0.5363 - loss: 1.0326 - val_accuracy: 0.3250 - val_loss: 1.9361 - learning_rate: 0.0010
# Epoch 5/30
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 308ms/step - accuracy: 0.5995 - loss: 0.8240
# Epoch 5: val_accuracy improved from 0.32500 to 0.45000, saving model to EFNetB7-ft.keras
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 14s 353ms/step - accuracy: 0.6004 - loss: 0.8238 - val_accuracy: 0.4500 - val_loss: 1.2611 - learning_rate: 0.0010
# Epoch 6/30
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 308ms/step - accuracy: 0.6835 - loss: 0.7303
# Epoch 6: val_accuracy did not improve from 0.45000
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 13s 325ms/step - accuracy: 0.6841 - loss: 0.7292 - val_accuracy: 0.3250 - val_loss: 3.4399 - learning_rate: 0.0010
# Epoch 7/30
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 308ms/step - accuracy: 0.8085 - loss: 0.5025
# Epoch 7: val_accuracy did not improve from 0.45000
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 13s 325ms/step - accuracy: 0.8082 - loss: 0.5023 - val_accuracy: 0.4000 - val_loss: 1.7181 - learning_rate: 0.0010
# Epoch 8/30
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 308ms/step - accuracy: 0.8744 - loss: 0.3775
# Epoch 8: val_accuracy improved from 0.45000 to 0.47500, saving model to EFNetB7-ft.keras
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 14s 355ms/step - accuracy: 0.8731 - loss: 0.3791 - val_accuracy: 0.4750 - val_loss: 2.1208 - learning_rate: 0.0010
# Epoch 9/30
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 308ms/step - accuracy: 0.7846 - loss: 0.5662
# Epoch 9: val_accuracy did not improve from 0.47500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 13s 325ms/step - accuracy: 0.7850 - loss: 0.5655 - val_accuracy: 0.4000 - val_loss: 1.5538 - learning_rate: 0.0010
# Epoch 10/30
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 308ms/step - accuracy: 0.8246 - loss: 0.4501
# Epoch 10: val_accuracy did not improve from 0.47500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 13s 325ms/step - accuracy: 0.8243 - loss: 0.4503 - val_accuracy: 0.3250 - val_loss: 6.5804 - learning_rate: 0.0010
# Epoch 11/30
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 308ms/step - accuracy: 0.8576 - loss: 0.3378
# Epoch 11: val_accuracy improved from 0.47500 to 0.55000, saving model to EFNetB7-ft.keras
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 14s 354ms/step - accuracy: 0.8578 - loss: 0.3374 - val_accuracy: 0.5500 - val_loss: 1.7705 - learning_rate: 0.0010
# Epoch 12/30
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 308ms/step - accuracy: 0.8032 - loss: 0.4740
# Epoch 12: val_accuracy did not improve from 0.55000
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 13s 325ms/step - accuracy: 0.8042 - loss: 0.4727 - val_accuracy: 0.4750 - val_loss: 2.6162 - learning_rate: 0.0010
# Epoch 13/30
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 308ms/step - accuracy: 0.8385 - loss: 0.3499
# Epoch 13: val_accuracy did not improve from 0.55000
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 20s 325ms/step - accuracy: 0.8388 - loss: 0.3503 - val_accuracy: 0.2250 - val_loss: 6.1860 - learning_rate: 0.0010
# Epoch 14/30
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 308ms/step - accuracy: 0.8507 - loss: 0.3926
# Epoch 14: val_accuracy did not improve from 0.55000
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 13s 325ms/step - accuracy: 0.8509 - loss: 0.3924 - val_accuracy: 0.3750 - val_loss: 1.9787 - learning_rate: 0.0010
# Epoch 15/30
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 308ms/step - accuracy: 0.9250 - loss: 0.2120
# Epoch 15: val_accuracy improved from 0.55000 to 0.75000, saving model to EFNetB7-ft.keras
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 14s 354ms/step - accuracy: 0.9246 - loss: 0.2131 - val_accuracy: 0.7500 - val_loss: 1.1378 - learning_rate: 0.0010
# Epoch 16/30
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 308ms/step - accuracy: 0.9253 - loss: 0.2709
# Epoch 16: val_accuracy did not improve from 0.75000
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 13s 325ms/step - accuracy: 0.9250 - loss: 0.2710 - val_accuracy: 0.5500 - val_loss: 1.4664 - learning_rate: 0.0010
# Epoch 17/30
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 309ms/step - accuracy: 0.9215 - loss: 0.2055
# Epoch 17: val_accuracy did not improve from 0.75000
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 13s 326ms/step - accuracy: 0.9213 - loss: 0.2063 - val_accuracy: 0.7500 - val_loss: 1.1492 - learning_rate: 0.0010
# Epoch 18/30
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 308ms/step - accuracy: 0.8844 - loss: 0.3059
# Epoch 18: val_accuracy did not improve from 0.75000
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 13s 325ms/step - accuracy: 0.8847 - loss: 0.3042 - val_accuracy: 0.5750 - val_loss: 1.4939 - learning_rate: 0.0010
# Epoch 19/30
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 309ms/step - accuracy: 0.9623 - loss: 0.1330
# Epoch 19: val_accuracy did not improve from 0.75000
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 13s 326ms/step - accuracy: 0.9618 - loss: 0.1330 - val_accuracy: 0.5000 - val_loss: 1.9894 - learning_rate: 0.0010
# Epoch 20/30
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 308ms/step - accuracy: 0.9697 - loss: 0.0921
# Epoch 20: val_accuracy did not improve from 0.75000
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 13s 325ms/step - accuracy: 0.9692 - loss: 0.0936 - val_accuracy: 0.6000 - val_loss: 1.8214 - learning_rate: 0.0010
# Epoch 21/30
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 308ms/step - accuracy: 0.9232 - loss: 0.1505
# Epoch 21: val_accuracy did not improve from 0.75000
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 13s 325ms/step - accuracy: 0.9229 - loss: 0.1517 - val_accuracy: 0.2000 - val_loss: 4.3665 - learning_rate: 0.0010
# Epoch 22/30
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 308ms/step - accuracy: 0.8769 - loss: 0.2885
# Epoch 22: val_accuracy did not improve from 0.75000
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 13s 325ms/step - accuracy: 0.8779 - loss: 0.2870 - val_accuracy: 0.7250 - val_loss: 0.8614 - learning_rate: 0.0010
# Epoch 23/30
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 308ms/step - accuracy: 0.9415 - loss: 0.2129
# Epoch 23: ReduceLROnPlateau reducing learning rate to 0.0006000000284984708.
#
# Epoch 23: val_accuracy did not improve from 0.75000
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 13s 326ms/step - accuracy: 0.9420 - loss: 0.2115 - val_accuracy: 0.6250 - val_loss: 1.2688 - learning_rate: 0.0010
# Epoch 24/30
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 308ms/step - accuracy: 0.9248 - loss: 0.1994
# Epoch 24: val_accuracy did not improve from 0.75000
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 13s 325ms/step - accuracy: 0.9248 - loss: 0.1994 - val_accuracy: 0.5250 - val_loss: 1.1795 - learning_rate: 6.0000e-04
# Epoch 25/30
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 308ms/step - accuracy: 0.9808 - loss: 0.0821
# Epoch 25: val_accuracy did not improve from 0.75000
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 13s 325ms/step - accuracy: 0.9805 - loss: 0.0826 - val_accuracy: 0.3250 - val_loss: 2.5952 - learning_rate: 6.0000e-04
# Epoch 26/30
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 308ms/step - accuracy: 0.9259 - loss: 0.1686
# Epoch 26: val_accuracy did not improve from 0.75000
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 13s 325ms/step - accuracy: 0.9264 - loss: 0.1675 - val_accuracy: 0.7250 - val_loss: 0.7753 - learning_rate: 6.0000e-04
# Epoch 27/30
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 308ms/step - accuracy: 0.9698 - loss: 0.1003
# Epoch 27: val_accuracy did not improve from 0.75000
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 13s 325ms/step - accuracy: 0.9699 - loss: 0.1001 - val_accuracy: 0.7000 - val_loss: 0.6694 - learning_rate: 6.0000e-04
# Epoch 28/30
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 308ms/step - accuracy: 1.0000 - loss: 0.0178
# Epoch 28: val_accuracy did not improve from 0.75000
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 13s 325ms/step - accuracy: 1.0000 - loss: 0.0178 - val_accuracy: 0.7500 - val_loss: 0.6815 - learning_rate: 6.0000e-04
# Epoch 29/30
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 308ms/step - accuracy: 0.9846 - loss: 0.0346
# Epoch 29: val_accuracy did not improve from 0.75000
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 13s 325ms/step - accuracy: 0.9847 - loss: 0.0345 - val_accuracy: 0.5500 - val_loss: 1.3726 - learning_rate: 6.0000e-04
# Epoch 30/30
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 308ms/step - accuracy: 0.9900 - loss: 0.0348
# Epoch 30: val_accuracy did not improve from 0.75000
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 13s 324ms/step - accuracy: 0.9900 - loss: 0.0350 - val_accuracy: 0.7000 - val_loss: 0.7093 - learning_rate: 6.0000e-04
