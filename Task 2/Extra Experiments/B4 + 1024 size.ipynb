# %%
import tensorflow as tf
import keras 
import matplotlib.pyplot as plt
import numpy as np
import cv2
import os
import sys
import random
import os                      
import numpy as np              
import pandas as pd             
import torch             
from PIL import Image, ImageOps, ImageFilter
import matplotlib.pyplot as plt 
import torch.nn as nn           
from torch.utils.data import DataLoader  
from PIL import Image          
import torch.nn.functional as F 
import torchvision.transforms as transforms   
from torchvision.utils import make_grid    
from torchvision.datasets import ImageFolder  
from torch.utils.data import random_split
from tensorflow.keras.layers import Input

# %matplotlib inline

# %%
from keras.preprocessing import image
from keras.applications.imagenet_utils import decode_predictions, preprocess_input
from keras.models import Model
from keras.layers import Flatten, Dense, Dropout

# %%
input_shape = (1024, 1024, 3)
input_layer = Input(shape=input_shape)
model = keras.applications.EfficientNetB4(input_tensor=input_layer,weights='imagenet', include_top=True)
# Out:
# Downloading data from https://storage.googleapis.com/keras-applications/efficientnetb4.h5
# 78864416/78864416 ━━━━━━━━━━━━━━━━━━━━ 1s 0us/step

# %%
for layer in model.layers[0:8]:
    layer.trainable = False
    
    
for i, layer in enumerate(model.layers):
    print(i, layer.name, layer.trainable)
# Out:
# 0 input_layer False
# 1 rescaling False
# 2 normalization False
# 3 rescaling_1 False
# 4 stem_conv_pad False
# 5 stem_conv False
# 6 stem_bn False
# 7 stem_activation False
# 8 block1a_dwconv True
# 9 block1a_bn True
# 10 block1a_activation True
# 11 block1a_se_squeeze True
# 12 block1a_se_reshape True
# 13 block1a_se_reduce True
# 14 block1a_se_expand True
# 15 block1a_se_excite True
# 16 block1a_project_conv True
# 17 block1a_project_bn True
# 18 block1b_dwconv True
# 19 block1b_bn True
# 20 block1b_activation True
# 21 block1b_se_squeeze True
# 22 block1b_se_reshape True
# 23 block1b_se_reduce True
# 24 block1b_se_expand True
# 25 block1b_se_excite True
# 26 block1b_project_conv True
# 27 block1b_project_bn True
# 28 block1b_drop True
# 29 block1b_add True
# 30 block2a_expand_conv True
# 31 block2a_expand_bn True
# 32 block2a_expand_activation True
# 33 block2a_dwconv_pad True
# 34 block2a_dwconv True
# 35 block2a_bn True
# 36 block2a_activation True
# 37 block2a_se_squeeze True
# 38 block2a_se_reshape True
# 39 block2a_se_reduce True
# 40 block2a_se_expand True
# 41 block2a_se_excite True
# 42 block2a_project_conv True
# 43 block2a_project_bn True
# 44 block2b_expand_conv True
# 45 block2b_expand_bn True
# 46 block2b_expand_activation True
# 47 block2b_dwconv True
# 48 block2b_bn True
# 49 block2b_activation True
# 50 block2b_se_squeeze True
# 51 block2b_se_reshape True
# 52 block2b_se_reduce True
# 53 block2b_se_expand True
# 54 block2b_se_excite True
# 55 block2b_project_conv True
# 56 block2b_project_bn True
# 57 block2b_drop True
# 58 block2b_add True
# 59 block2c_expand_conv True
# 60 block2c_expand_bn True
# 61 block2c_expand_activation True
# 62 block2c_dwconv True
# 63 block2c_bn True
# 64 block2c_activation True
# 65 block2c_se_squeeze True
# 66 block2c_se_reshape True
# 67 block2c_se_reduce True
# 68 block2c_se_expand True
# 69 block2c_se_excite True
# 70 block2c_project_conv True
# 71 block2c_project_bn True
# 72 block2c_drop True
# 73 block2c_add True
# 74 block2d_expand_conv True
# 75 block2d_expand_bn True
# 76 block2d_expand_activation True
# 77 block2d_dwconv True
# 78 block2d_bn True
# 79 block2d_activation True
# 80 block2d_se_squeeze True
# 81 block2d_se_reshape True
# 82 block2d_se_reduce True
# 83 block2d_se_expand True
# 84 block2d_se_excite True
# 85 block2d_project_conv True
# 86 block2d_project_bn True
# 87 block2d_drop True
# 88 block2d_add True
# 89 block3a_expand_conv True
# 90 block3a_expand_bn True
# 91 block3a_expand_activation True
# 92 block3a_dwconv_pad True
# 93 block3a_dwconv True
# 94 block3a_bn True
# 95 block3a_activation True
# 96 block3a_se_squeeze True
# 97 block3a_se_reshape True
# 98 block3a_se_reduce True
# 99 block3a_se_expand True
# 100 block3a_se_excite True
# 101 block3a_project_conv True
# 102 block3a_project_bn True
# 103 block3b_expand_conv True
# 104 block3b_expand_bn True
# 105 block3b_expand_activation True
# 106 block3b_dwconv True
# 107 block3b_bn True
# 108 block3b_activation True
# 109 block3b_se_squeeze True
# 110 block3b_se_reshape True
# 111 block3b_se_reduce True
# 112 block3b_se_expand True
# 113 block3b_se_excite True
# 114 block3b_project_conv True
# 115 block3b_project_bn True
# 116 block3b_drop True
# 117 block3b_add True
# 118 block3c_expand_conv True
# 119 block3c_expand_bn True
# 120 block3c_expand_activation True
# 121 block3c_dwconv True
# 122 block3c_bn True
# 123 block3c_activation True
# 124 block3c_se_squeeze True
# 125 block3c_se_reshape True
# 126 block3c_se_reduce True
# 127 block3c_se_expand True
# 128 block3c_se_excite True
# 129 block3c_project_conv True
# 130 block3c_project_bn True
# 131 block3c_drop True
# 132 block3c_add True
# 133 block3d_expand_conv True
# 134 block3d_expand_bn True
# 135 block3d_expand_activation True
# 136 block3d_dwconv True
# 137 block3d_bn True
# 138 block3d_activation True
# 139 block3d_se_squeeze True
# 140 block3d_se_reshape True
# 141 block3d_se_reduce True
# 142 block3d_se_expand True
# 143 block3d_se_excite True
# 144 block3d_project_conv True
# 145 block3d_project_bn True
# 146 block3d_drop True
# 147 block3d_add True
# 148 block4a_expand_conv True
# 149 block4a_expand_bn True
# 150 block4a_expand_activation True
# 151 block4a_dwconv_pad True
# 152 block4a_dwconv True
# 153 block4a_bn True
# 154 block4a_activation True
# 155 block4a_se_squeeze True
# 156 block4a_se_reshape True
# 157 block4a_se_reduce True
# 158 block4a_se_expand True
# 159 block4a_se_excite True
# 160 block4a_project_conv True
# 161 block4a_project_bn True
# 162 block4b_expand_conv True
# 163 block4b_expand_bn True
# 164 block4b_expand_activation True
# 165 block4b_dwconv True
# 166 block4b_bn True
# 167 block4b_activation True
# 168 block4b_se_squeeze True
# 169 block4b_se_reshape True
# 170 block4b_se_reduce True
# 171 block4b_se_expand True
# 172 block4b_se_excite True
# 173 block4b_project_conv True
# 174 block4b_project_bn True
# 175 block4b_drop True
# 176 block4b_add True
# 177 block4c_expand_conv True
# 178 block4c_expand_bn True
# 179 block4c_expand_activation True
# 180 block4c_dwconv True
# 181 block4c_bn True
# 182 block4c_activation True
# 183 block4c_se_squeeze True
# 184 block4c_se_reshape True
# 185 block4c_se_reduce True
# 186 block4c_se_expand True
# 187 block4c_se_excite True
# 188 block4c_project_conv True
# 189 block4c_project_bn True
# 190 block4c_drop True
# 191 block4c_add True
# 192 block4d_expand_conv True
# 193 block4d_expand_bn True
# 194 block4d_expand_activation True
# 195 block4d_dwconv True
# 196 block4d_bn True
# 197 block4d_activation True
# 198 block4d_se_squeeze True
# 199 block4d_se_reshape True
# 200 block4d_se_reduce True
# 201 block4d_se_expand True
# 202 block4d_se_excite True
# 203 block4d_project_conv True
# 204 block4d_project_bn True
# 205 block4d_drop True
# 206 block4d_add True
# 207 block4e_expand_conv True
# 208 block4e_expand_bn True
# 209 block4e_expand_activation True
# 210 block4e_dwconv True
# 211 block4e_bn True
# 212 block4e_activation True
# 213 block4e_se_squeeze True
# 214 block4e_se_reshape True
# 215 block4e_se_reduce True
# 216 block4e_se_expand True
# 217 block4e_se_excite True
# 218 block4e_project_conv True
# 219 block4e_project_bn True
# 220 block4e_drop True
# 221 block4e_add True
# 222 block4f_expand_conv True
# 223 block4f_expand_bn True
# 224 block4f_expand_activation True
# 225 block4f_dwconv True
# 226 block4f_bn True
# 227 block4f_activation True
# 228 block4f_se_squeeze True
# 229 block4f_se_reshape True
# 230 block4f_se_reduce True
# 231 block4f_se_expand True
# 232 block4f_se_excite True
# 233 block4f_project_conv True
# 234 block4f_project_bn True
# 235 block4f_drop True
# 236 block4f_add True
# 237 block5a_expand_conv True
# 238 block5a_expand_bn True
# 239 block5a_expand_activation True
# 240 block5a_dwconv True
# 241 block5a_bn True
# 242 block5a_activation True
# 243 block5a_se_squeeze True
# 244 block5a_se_reshape True
# 245 block5a_se_reduce True
# 246 block5a_se_expand True
# 247 block5a_se_excite True
# 248 block5a_project_conv True
# 249 block5a_project_bn True
# 250 block5b_expand_conv True
# 251 block5b_expand_bn True
# 252 block5b_expand_activation True
# 253 block5b_dwconv True
# 254 block5b_bn True
# 255 block5b_activation True
# 256 block5b_se_squeeze True
# 257 block5b_se_reshape True
# 258 block5b_se_reduce True
# 259 block5b_se_expand True
# 260 block5b_se_excite True
# 261 block5b_project_conv True
# 262 block5b_project_bn True
# 263 block5b_drop True
# 264 block5b_add True
# 265 block5c_expand_conv True
# 266 block5c_expand_bn True
# 267 block5c_expand_activation True
# 268 block5c_dwconv True
# 269 block5c_bn True
# 270 block5c_activation True
# 271 block5c_se_squeeze True
# 272 block5c_se_reshape True
# 273 block5c_se_reduce True
# 274 block5c_se_expand True
# 275 block5c_se_excite True
# 276 block5c_project_conv True
# 277 block5c_project_bn True
# 278 block5c_drop True
# 279 block5c_add True
# 280 block5d_expand_conv True
# 281 block5d_expand_bn True
# 282 block5d_expand_activation True
# 283 block5d_dwconv True
# 284 block5d_bn True
# 285 block5d_activation True
# 286 block5d_se_squeeze True
# 287 block5d_se_reshape True
# 288 block5d_se_reduce True
# 289 block5d_se_expand True
# 290 block5d_se_excite True
# 291 block5d_project_conv True
# 292 block5d_project_bn True
# 293 block5d_drop True
# 294 block5d_add True
# 295 block5e_expand_conv True
# 296 block5e_expand_bn True
# 297 block5e_expand_activation True
# 298 block5e_dwconv True
# 299 block5e_bn True
# 300 block5e_activation True
# 301 block5e_se_squeeze True
# 302 block5e_se_reshape True
# 303 block5e_se_reduce True
# 304 block5e_se_expand True
# 305 block5e_se_excite True
# 306 block5e_project_conv True
# 307 block5e_project_bn True
# 308 block5e_drop True
# 309 block5e_add True
# 310 block5f_expand_conv True
# 311 block5f_expand_bn True
# 312 block5f_expand_activation True
# 313 block5f_dwconv True
# 314 block5f_bn True
# 315 block5f_activation True
# 316 block5f_se_squeeze True
# 317 block5f_se_reshape True
# 318 block5f_se_reduce True
# 319 block5f_se_expand True
# 320 block5f_se_excite True
# 321 block5f_project_conv True
# 322 block5f_project_bn True
# 323 block5f_drop True
# 324 block5f_add True
# 325 block6a_expand_conv True
# 326 block6a_expand_bn True
# 327 block6a_expand_activation True
# 328 block6a_dwconv_pad True
# 329 block6a_dwconv True
# 330 block6a_bn True
# 331 block6a_activation True
# 332 block6a_se_squeeze True
# 333 block6a_se_reshape True
# 334 block6a_se_reduce True
# 335 block6a_se_expand True
# 336 block6a_se_excite True
# 337 block6a_project_conv True
# 338 block6a_project_bn True
# 339 block6b_expand_conv True
# 340 block6b_expand_bn True
# 341 block6b_expand_activation True
# 342 block6b_dwconv True
# 343 block6b_bn True
# 344 block6b_activation True
# 345 block6b_se_squeeze True
# 346 block6b_se_reshape True
# 347 block6b_se_reduce True
# 348 block6b_se_expand True
# 349 block6b_se_excite True
# 350 block6b_project_conv True
# 351 block6b_project_bn True
# 352 block6b_drop True
# 353 block6b_add True
# 354 block6c_expand_conv True
# 355 block6c_expand_bn True
# 356 block6c_expand_activation True
# 357 block6c_dwconv True
# 358 block6c_bn True
# 359 block6c_activation True
# 360 block6c_se_squeeze True
# 361 block6c_se_reshape True
# 362 block6c_se_reduce True
# 363 block6c_se_expand True
# 364 block6c_se_excite True
# 365 block6c_project_conv True
# 366 block6c_project_bn True
# 367 block6c_drop True
# 368 block6c_add True
# 369 block6d_expand_conv True
# 370 block6d_expand_bn True
# 371 block6d_expand_activation True
# 372 block6d_dwconv True
# 373 block6d_bn True
# 374 block6d_activation True
# 375 block6d_se_squeeze True
# 376 block6d_se_reshape True
# 377 block6d_se_reduce True
# 378 block6d_se_expand True
# 379 block6d_se_excite True
# 380 block6d_project_conv True
# 381 block6d_project_bn True
# 382 block6d_drop True
# 383 block6d_add True
# 384 block6e_expand_conv True
# 385 block6e_expand_bn True
# 386 block6e_expand_activation True
# 387 block6e_dwconv True
# 388 block6e_bn True
# 389 block6e_activation True
# 390 block6e_se_squeeze True
# 391 block6e_se_reshape True
# 392 block6e_se_reduce True
# 393 block6e_se_expand True
# 394 block6e_se_excite True
# 395 block6e_project_conv True
# 396 block6e_project_bn True
# 397 block6e_drop True
# 398 block6e_add True
# 399 block6f_expand_conv True
# 400 block6f_expand_bn True
# 401 block6f_expand_activation True
# 402 block6f_dwconv True
# 403 block6f_bn True
# 404 block6f_activation True
# 405 block6f_se_squeeze True
# 406 block6f_se_reshape True
# 407 block6f_se_reduce True
# 408 block6f_se_expand True
# 409 block6f_se_excite True
# 410 block6f_project_conv True
# 411 block6f_project_bn True
# 412 block6f_drop True
# 413 block6f_add True
# 414 block6g_expand_conv True
# 415 block6g_expand_bn True
# 416 block6g_expand_activation True
# 417 block6g_dwconv True
# 418 block6g_bn True
# 419 block6g_activation True
# 420 block6g_se_squeeze True
# 421 block6g_se_reshape True
# 422 block6g_se_reduce True
# 423 block6g_se_expand True
# 424 block6g_se_excite True
# 425 block6g_project_conv True
# 426 block6g_project_bn True
# 427 block6g_drop True
# 428 block6g_add True
# 429 block6h_expand_conv True
# 430 block6h_expand_bn True
# 431 block6h_expand_activation True
# 432 block6h_dwconv True
# 433 block6h_bn True
# 434 block6h_activation True
# 435 block6h_se_squeeze True
# 436 block6h_se_reshape True
# 437 block6h_se_reduce True
# 438 block6h_se_expand True
# 439 block6h_se_excite True
# 440 block6h_project_conv True
# 441 block6h_project_bn True
# 442 block6h_drop True
# 443 block6h_add True
# 444 block7a_expand_conv True
# 445 block7a_expand_bn True
# 446 block7a_expand_activation True
# 447 block7a_dwconv True
# 448 block7a_bn True
# 449 block7a_activation True
# 450 block7a_se_squeeze True
# 451 block7a_se_reshape True
# 452 block7a_se_reduce True
# 453 block7a_se_expand True
# 454 block7a_se_excite True
# 455 block7a_project_conv True
# 456 block7a_project_bn True
# 457 block7b_expand_conv True
# 458 block7b_expand_bn True
# 459 block7b_expand_activation True
# 460 block7b_dwconv True
# 461 block7b_bn True
# 462 block7b_activation True
# 463 block7b_se_squeeze True
# 464 block7b_se_reshape True
# 465 block7b_se_reduce True
# 466 block7b_se_expand True
# 467 block7b_se_excite True
# 468 block7b_project_conv True
# 469 block7b_project_bn True
# 470 block7b_drop True
# 471 block7b_add True
# 472 top_conv True
# 473 top_bn True
# 474 top_activation True
# 475 avg_pool True
# 476 top_dropout True
# 477 predictions True

# %%
model = Model(inputs=model.input, outputs=model.get_layer("avg_pool").output)
model.input
# Out:
# [<KerasTensor shape=(None, 1024, 1024, 3), dtype=float32, sparse=None, name=keras_tensor>]

# %%
x = model.output
x = Dense(3, activation='softmax')(x)
model = Model(inputs=model.input, outputs=x)

# %%
from keras.callbacks import ReduceLROnPlateau
from keras.callbacks import ModelCheckpoint

lr_reduce = ReduceLROnPlateau(monitor='val_accuracy', factor=0.6, patience=8, verbose=1, mode='max', min_lr=5e-5)
checkpoint = ModelCheckpoint('EFNetB4-1024-ft.keras', monitor= 'val_accuracy', mode= 'max', save_best_only = True, verbose= 1)

# %%
import glob
data = glob.glob('/kaggle/input/transcend/train_images/train_images/*.*')

# %%
data[:5]
# Out:
# ['/kaggle/input/transcend/train_images/train_images/IMG_160.jpg',
#  '/kaggle/input/transcend/train_images/train_images/IMG_21.jpg',
#  '/kaggle/input/transcend/train_images/train_images/IMG_163.jpg',
#  '/kaggle/input/transcend/train_images/train_images/IMG_151.jpg',
#  '/kaggle/input/transcend/train_images/train_images/IMG_190.jpg']

# %%
ann = pd.read_csv('/kaggle/input/transcend/train_annotations.csv')
ann
# Out:
#             Name       State
# 0      IMG_1.jpg   malignant
# 1      IMG_2.jpg  non-nodule
# 2      IMG_3.jpg  non-nodule
# 3      IMG_4.jpg   malignant
# 4      IMG_5.jpg  non-nodule
# ..           ...         ...
# 195  IMG_196.jpg   malignant
# 196  IMG_197.jpg   malignant
# 197  IMG_198.jpg  non-nodule
# 198  IMG_199.jpg   malignant
# 199  IMG_200.jpg      benign
#
# [200 rows x 2 columns]

# %%
from PIL import Image, ImageOps, ImageFilter
image = Image.open('/kaggle/input/transcend/train_images/train_images/IMG_121.jpg').convert('RGB')

# %%
image.size
# Out:
# (2048, 2048)

# %%
ann['State'].replace({'benign': 0, 'non-nodule': 1, 'malignant': 2}, inplace=True)
ann
# Out:
# /tmp/ipykernel_34/1362740101.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   ann['State'].replace({'benign': 0, 'non-nodule': 1, 'malignant': 2}, inplace=True)
# /tmp/ipykernel_34/1362740101.py:1: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   ann['State'].replace({'benign': 0, 'non-nodule': 1, 'malignant': 2}, inplace=True)
#             Name  State
# 0      IMG_1.jpg      2
# 1      IMG_2.jpg      1
# 2      IMG_3.jpg      1
# 3      IMG_4.jpg      2
# 4      IMG_5.jpg      1
# ..           ...    ...
# 195  IMG_196.jpg      2
# 196  IMG_197.jpg      2
# 197  IMG_198.jpg      1
# 198  IMG_199.jpg      2
# 199  IMG_200.jpg      0
#
# [200 rows x 2 columns]

# %%
labels = []

for image_name in data:
    img_file_name = image_name.split('/')[-1]
    label = ann[ann['Name'] == img_file_name]['State'].values[0]
    labels.append(label)

# %%
from PIL import Image, ImageOps, ImageFilter
import numpy as np
import os
from sklearn.utils import shuffle

images = []

def preprocess_image(image_path):
    image = Image.open(image_path).convert('RGB')
    width, height = image.size
    pad = 1024
    image = image.resize((pad, pad))
    image = image.filter(ImageFilter.SHARPEN)
    image = np.array(image)
    images.append(image)


for i in data:
    preprocess_image(i)

# %%
images = np.array(images)
images.shape
# Out:
# (200, 1024, 1024, 3)

# %%
labels= np.array(labels)

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(images, labels, test_size=0.2, random_state=42)

# %%
from tensorflow.keras import layers, models, Model, optimizers
learning_rate= 5e-5
model.compile(loss="sparse_categorical_crossentropy", optimizer=optimizers.Adam(), metrics=["accuracy"])
history = model.fit(X_train, y_train, batch_size = 4, epochs=30, validation_data=(X_test,y_test), callbacks=[lr_reduce,checkpoint])
# Out:
# Epoch 1/30
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1710669576.073516     102 device_compiler.h:186] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# W0000 00:00:1710669576.278964     102 graph_launch.cc:671] Fallback to op-by-op mode because memset node breaks graph update
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 638ms/step - accuracy: 0.3914 - loss: 1.1971
# W0000 00:00:1710669611.619509     104 graph_launch.cc:671] Fallback to op-by-op mode because memset node breaks graph update
# Epoch 1: val_accuracy improved from -inf to 0.35000, saving model to EFNetB4-1024-ft.keras
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 239s 970ms/step - accuracy: 0.3924 - loss: 1.1971 - val_accuracy: 0.3500 - val_loss: 2.2406 - learning_rate: 0.0010
# Epoch 2/30
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 637ms/step - accuracy: 0.4917 - loss: 0.9966
# Epoch 2: val_accuracy did not improve from 0.35000
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 27s 671ms/step - accuracy: 0.4919 - loss: 0.9975 - val_accuracy: 0.3250 - val_loss: 9.4392 - learning_rate: 0.0010
# Epoch 3/30
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 637ms/step - accuracy: 0.5211 - loss: 1.2000
# Epoch 3: val_accuracy did not improve from 0.35000
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 27s 671ms/step - accuracy: 0.5212 - loss: 1.1966 - val_accuracy: 0.3250 - val_loss: 5.2241 - learning_rate: 0.0010
# Epoch 4/30
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 638ms/step - accuracy: 0.5442 - loss: 0.9555
# Epoch 4: val_accuracy did not improve from 0.35000
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 27s 672ms/step - accuracy: 0.5444 - loss: 0.9555 - val_accuracy: 0.3250 - val_loss: 16.4765 - learning_rate: 0.0010
# Epoch 5/30
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 638ms/step - accuracy: 0.6701 - loss: 0.7370
# Epoch 5: val_accuracy improved from 0.35000 to 0.37500, saving model to EFNetB4-1024-ft.keras
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 29s 720ms/step - accuracy: 0.6696 - loss: 0.7375 - val_accuracy: 0.3750 - val_loss: 1.6131 - learning_rate: 0.0010
# Epoch 6/30
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 636ms/step - accuracy: 0.6897 - loss: 0.7679
# Epoch 6: val_accuracy improved from 0.37500 to 0.42500, saving model to EFNetB4-1024-ft.keras
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 29s 718ms/step - accuracy: 0.6894 - loss: 0.7692 - val_accuracy: 0.4250 - val_loss: 4.1426 - learning_rate: 0.0010
# Epoch 7/30
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 637ms/step - accuracy: 0.7148 - loss: 0.7150
# Epoch 7: val_accuracy did not improve from 0.42500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 27s 671ms/step - accuracy: 0.7144 - loss: 0.7155 - val_accuracy: 0.4000 - val_loss: 3.7726 - learning_rate: 0.0010
# Epoch 8/30
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 638ms/step - accuracy: 0.6295 - loss: 0.7670
# Epoch 8: val_accuracy improved from 0.42500 to 0.50000, saving model to EFNetB4-1024-ft.keras
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 29s 720ms/step - accuracy: 0.6310 - loss: 0.7674 - val_accuracy: 0.5000 - val_loss: 7.9197 - learning_rate: 0.0010
# Epoch 9/30
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 638ms/step - accuracy: 0.7784 - loss: 0.6162
# Epoch 9: val_accuracy did not improve from 0.50000
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 27s 672ms/step - accuracy: 0.7771 - loss: 0.6175 - val_accuracy: 0.4000 - val_loss: 2.7520 - learning_rate: 0.0010
# Epoch 10/30
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 638ms/step - accuracy: 0.8415 - loss: 0.4953
# Epoch 10: val_accuracy did not improve from 0.50000
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 27s 673ms/step - accuracy: 0.8414 - loss: 0.4965 - val_accuracy: 0.4250 - val_loss: 1.7432 - learning_rate: 0.0010
# Epoch 11/30
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 637ms/step - accuracy: 0.7287 - loss: 0.6658
# Epoch 11: val_accuracy did not improve from 0.50000
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 27s 672ms/step - accuracy: 0.7289 - loss: 0.6655 - val_accuracy: 0.5000 - val_loss: 3.1066 - learning_rate: 0.0010
# Epoch 12/30
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 638ms/step - accuracy: 0.8551 - loss: 0.4621
# Epoch 12: val_accuracy did not improve from 0.50000
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 27s 672ms/step - accuracy: 0.8552 - loss: 0.4618 - val_accuracy: 0.3250 - val_loss: 2.7426 - learning_rate: 0.0010
# Epoch 13/30
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 638ms/step - accuracy: 0.8248 - loss: 0.4725
# Epoch 13: val_accuracy did not improve from 0.50000
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 27s 672ms/step - accuracy: 0.8243 - loss: 0.4722 - val_accuracy: 0.5000 - val_loss: 2.6454 - learning_rate: 0.0010
# Epoch 14/30
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 639ms/step - accuracy: 0.8996 - loss: 0.2780
# Epoch 14: val_accuracy did not improve from 0.50000
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 27s 673ms/step - accuracy: 0.8992 - loss: 0.2791 - val_accuracy: 0.4250 - val_loss: 2.3636 - learning_rate: 0.0010
# Epoch 15/30
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 637ms/step - accuracy: 0.8976 - loss: 0.3338
# Epoch 15: val_accuracy did not improve from 0.50000
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 27s 672ms/step - accuracy: 0.8964 - loss: 0.3351 - val_accuracy: 0.5000 - val_loss: 2.6653 - learning_rate: 0.0010
# Epoch 16/30
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 636ms/step - accuracy: 0.8455 - loss: 0.4050
# Epoch 16: ReduceLROnPlateau reducing learning rate to 0.0006000000284984708.
#
# Epoch 16: val_accuracy did not improve from 0.50000
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 27s 670ms/step - accuracy: 0.8460 - loss: 0.4029 - val_accuracy: 0.4250 - val_loss: 1.9727 - learning_rate: 0.0010
# Epoch 17/30
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 636ms/step - accuracy: 0.9412 - loss: 0.1903
# Epoch 17: val_accuracy did not improve from 0.50000
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 27s 671ms/step - accuracy: 0.9405 - loss: 0.1910 - val_accuracy: 0.4750 - val_loss: 2.9598 - learning_rate: 6.0000e-04
# Epoch 18/30
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 637ms/step - accuracy: 0.8714 - loss: 0.4051
# Epoch 18: val_accuracy did not improve from 0.50000
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 27s 671ms/step - accuracy: 0.8715 - loss: 0.4045 - val_accuracy: 0.5000 - val_loss: 2.6414 - learning_rate: 6.0000e-04
# Epoch 19/30
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 637ms/step - accuracy: 0.9026 - loss: 0.3323
# Epoch 19: val_accuracy improved from 0.50000 to 0.60000, saving model to EFNetB4-1024-ft.keras
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 29s 722ms/step - accuracy: 0.9041 - loss: 0.3287 - val_accuracy: 0.6000 - val_loss: 1.1695 - learning_rate: 6.0000e-04
# Epoch 20/30
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 638ms/step - accuracy: 0.9553 - loss: 0.1481
# Epoch 20: val_accuracy did not improve from 0.60000
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 39s 672ms/step - accuracy: 0.9550 - loss: 0.1487 - val_accuracy: 0.5750 - val_loss: 1.8257 - learning_rate: 6.0000e-04
# Epoch 21/30
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 636ms/step - accuracy: 0.9931 - loss: 0.0526
# Epoch 21: val_accuracy did not improve from 0.60000
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 27s 671ms/step - accuracy: 0.9931 - loss: 0.0525 - val_accuracy: 0.5750 - val_loss: 1.2443 - learning_rate: 6.0000e-04
# Epoch 22/30
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 638ms/step - accuracy: 0.9436 - loss: 0.1031
# Epoch 22: val_accuracy did not improve from 0.60000
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 28s 703ms/step - accuracy: 0.9445 - loss: 0.1020 - val_accuracy: 0.6000 - val_loss: 1.2282 - learning_rate: 6.0000e-04
# Epoch 23/30
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 637ms/step - accuracy: 0.9758 - loss: 0.1810
# Epoch 23: val_accuracy did not improve from 0.60000
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 27s 672ms/step - accuracy: 0.9754 - loss: 0.1815 - val_accuracy: 0.4000 - val_loss: 3.8508 - learning_rate: 6.0000e-04
# Epoch 24/30
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 637ms/step - accuracy: 0.9567 - loss: 0.1314
# Epoch 24: val_accuracy did not improve from 0.60000
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 27s 672ms/step - accuracy: 0.9565 - loss: 0.1317 - val_accuracy: 0.6000 - val_loss: 1.2030 - learning_rate: 6.0000e-04
# Epoch 25/30
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 638ms/step - accuracy: 0.9332 - loss: 0.1434
# Epoch 25: val_accuracy did not improve from 0.60000
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 27s 673ms/step - accuracy: 0.9336 - loss: 0.1430 - val_accuracy: 0.3250 - val_loss: 4.1827 - learning_rate: 6.0000e-04
# Epoch 26/30
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 637ms/step - accuracy: 0.9940 - loss: 0.0871
# Epoch 26: val_accuracy improved from 0.60000 to 0.62500, saving model to EFNetB4-1024-ft.keras
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 29s 719ms/step - accuracy: 0.9940 - loss: 0.0869 - val_accuracy: 0.6250 - val_loss: 1.3510 - learning_rate: 6.0000e-04
# Epoch 27/30
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 637ms/step - accuracy: 0.9863 - loss: 0.0371
# Epoch 27: val_accuracy did not improve from 0.62500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 27s 671ms/step - accuracy: 0.9865 - loss: 0.0371 - val_accuracy: 0.6000 - val_loss: 1.7694 - learning_rate: 6.0000e-04
# Epoch 28/30
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 637ms/step - accuracy: 1.0000 - loss: 0.0327
# Epoch 28: val_accuracy did not improve from 0.62500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 27s 671ms/step - accuracy: 1.0000 - loss: 0.0325 - val_accuracy: 0.5500 - val_loss: 1.8719 - learning_rate: 6.0000e-04
# Epoch 29/30
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 637ms/step - accuracy: 0.9795 - loss: 0.0444
# Epoch 29: val_accuracy did not improve from 0.62500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 27s 671ms/step - accuracy: 0.9799 - loss: 0.0438 - val_accuracy: 0.5000 - val_loss: 1.6383 - learning_rate: 6.0000e-04
# Epoch 30/30
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 637ms/step - accuracy: 0.9442 - loss: 0.2049
# Epoch 30: val_accuracy did not improve from 0.62500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 27s 671ms/step - accuracy: 0.9442 - loss: 0.2047 - val_accuracy: 0.3750 - val_loss: 1.6527 - learning_rate: 6.0000e-04
